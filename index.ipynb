# %% [markdown]
# # Regression Model Validation - Lab
#
# ## Introduction
#
# In this lab, you'll be able to validate your model using train-test-split.
#
#
# ## Objectives
#
# You will be able to:
#
# - Calculate the mean squared error (MSE) as a measure of predictive performance
# - Validate the model using the test data

# %% [markdown]
# ## Let's use our Boston Housing Data again!
#
# This time, let's only include the variables that were previously selected using recursive feature elimination. We included the code to preprocess below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import load_boston

boston = load_boston()

boston_features = pd.DataFrame(boston.data, columns = boston.feature_names)
b = boston_features["B"]
logdis = np.log(boston_features["DIS"])
loglstat = np.log(boston_features["LSTAT"])

# minmax scaling
boston_features["B"] = (b-min(b))/(max(b)-min(b))
boston_features["DIS"] = (logdis-min(logdis))/(max(logdis)-min(logdis))

#standardization
boston_features["LSTAT"] = (loglstat-np.mean(loglstat))/np.sqrt(np.var(loglstat))

# %%
X = boston_features[['CHAS', 'RM', 'DIS', 'B', 'LSTAT']]
y = pd.DataFrame(boston.target, columns = ['price'])

# %% [markdown]
# ## Perform a train-test-split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2)
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 404 102 404 102

# %% [markdown]
# ## Apply your model to the train set

# %% [markdown]
# #### Importing and initializing the model class

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()

# %% [markdown]
# #### Fitting the model to the train data

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# #### Calculating predictions on the train set, and on the test set

# %%
y_hat_train = linreg.predict(X_train)
y_hat_test = linreg.predict(X_test)

# %% [markdown]
# #### Calculating your residuals

# %%
train_residuals = y_hat_train - y_train
test_residuals = y_hat_test - y_test

# %% [markdown]
# #### Calculating the Mean Squared Error
# A good way to compare overall performance is to compare the mean squarred error for the predicted values on the train and test sets.

# %%
from sklearn.metrics import mean_squared_error

train_mse = mean_squared_error(y_train, y_hat_train)
test_mse = mean_squared_error(y_test, y_hat_test)
print('Train Mean Squared Error:', train_mse)
print('Test Mean Squared Error:', test_mse)
# Out:
# Train Mean Squared Error: 21.774216654648654
# Test Mean Squared Error: 22.105610809394317

# %% [markdown]
# If your test error is substantially worse then our train error, this is a sign that our model doesn't generalize well to future cases.

# %% [markdown]
# One simple way to demonstrate overfitting and underfitting is to alter the size of our train test split. By default, scikit learn's built in method allocates 25% of the data to the test set and 75% to the training set. Fitting a model on only 10% of the data is apt to lead to underfitting, while training a model on 99% of the data is apt to lead to overfitting.

# %% [markdown]
# # Evaluating the effect of train-test split size
#
# Iterate over a range of train-test split sizes from .5 to .95. For each of these, generate a new train/test split sample. Fit a model to the training sample and calculate both the training error and the test error (mse) for each of these splits. Plot these two curves (train error vs. training size and test error vs. training size) on a graph.

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

train_errors = []
test_errors = []
for i in range(1, 100, 5):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = i/100)
    linreg.fit(X_train, y_train)
    y_hat_train = linreg.predict(X_train)
    y_hat_test = linreg.predict(X_test)
#     train_residuals = y_hat_train - y_train
#     test_residuals = y_hat_test - y_test
    train_errors.append(mean_squared_error(y_train, y_hat_train))
    test_errors.append(mean_squared_error(y_test, y_hat_test))

plt.figure(figsize=(25, 10))
plt.scatter(range(1, 100, 5), test_errors, color = 'r', label = 'Test Errors')
plt.scatter(range(1, 100, 5), train_errors, color = 'b', label = 'Training Errors')
plt.legend()

# %% [markdown]
# # Evaluating the effect of train-test split size: extension
#
# Repeat the previous example, but for each train-test split size, generate 100 iterations of models/errors and save the average train/test error. This will help account for any particularly good/bad models that might have resulted from poor/good splits in the data.

# %%
train_errors = []
test_errors = []
for i in range(1, 100, 5):
    sample_train_errors = []
    sample_test_errors = []
    for j in range(0, 100):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = i/100)
        linreg.fit(X_train, y_train)
        y_hat_train = linreg.predict(X_train)
        y_hat_test = linreg.predict(X_test)
#         train_residuals = y_hat_train - y_train
#         test_residuals = y_hat_test - y_test
        sample_train_errors.append(mean_squared_error(y_train, y_hat_train))
        sample_test_errors.append(mean_squared_error(y_test, y_hat_test))
    train_errors.append(np.mean(sample_train_errors))
    test_errors.append(np.mean(sample_test_errors))

plt.figure(figsize=(25, 10))
plt.scatter(range(1, 100, 5), test_errors, color = 'r', label = 'Test Errors')
plt.scatter(range(1, 100, 5), train_errors, color = 'b', label = 'Training Errors')
plt.legend()

# %% [markdown]
# What's happening here? evaluate your result!
#
# As the test split gets smaller and smaller, the difference between the prediction and the actual is more likely to be in the extremes. With such a narrow split, the likelihood of the model to appear to be overfitted increases.

# %% [markdown]
# ##  Summary

# %% [markdown]
# Congratulations! You now practiced your knowledge on MSE and on using train-test-split.
